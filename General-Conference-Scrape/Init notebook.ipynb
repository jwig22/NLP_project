# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (4.11.1)
# Collecting requests_html==0.10.0
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: w3lib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests_html==0.10.0->-r ./requirements.txt (line 3)) (2.0.1)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 KB 22.4 MB/s eta 0:00:00
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4->-r ./requirements.txt (line 2)) (2.3.2.post1)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 29.7 MB/s eta 0:00:00
# Collecting appdirs<2.0.0,>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html==0.10.0->-r ./requirements.txt (line 3)) (4.64.1)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests_html==0.10.0->-r ./requirements.txt (line 3)) (5.0.0)
# Requirement already satisfied: cssselect>0.7.9 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyquery->requests_html==0.10.0->-r ./requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyquery->requests_html==0.10.0->-r ./requirements.txt (line 3)) (4.9.1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html==0.10.0->-r ./requirements.txt (line 3)) (3.9.0)
# Building wheels for collected packages: bs4, fake-useragent, parse
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=a6eea08ae555d73482739691d841e027845717990955fc2b7ba37cc888f0e2ab
#   Stored in directory: /root/.cache/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=9223331b0d669c7e2d83be397969f7722954847b1c31402b9baaf01949a5aabb
#   Stored in directory: /root/.cache/pip/wheels/ae/e7/76/7dd44644d065268ab0e1b4fa2e802fa4bb0157717b7d6c6d92
#   Building wheel for parse (setup.py): started
#   Building wheel for parse (setup.py): finished with status 'done'
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=a018e777207f91c49cc5ca3ca63735979e01f0e001af63797d3eb03be14f9641
#   Stored in directory: /root/.cache/pip/wheels/d6/9c/58/ee3ba36897e890f3ad81e9b730791a153fce20caa4a8a474df
# Successfully built bs4 fake-useragent parse
# Installing collected packages: pyee, parse, fake-useragent, appdirs, websockets, pyquery, pyppeteer, bs4, requests_html
# Successfully installed appdirs-1.4.4 bs4-0.0.1 fake-useragent-0.1.11 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests_html-0.10.0 websockets-10.4
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=619af452-f7bc-47b4-b851-bf0578659355' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
